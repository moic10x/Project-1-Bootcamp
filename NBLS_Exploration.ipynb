# %%
import pandas as pd
from pathlib import Path

# %%
#create another column grabbing just the first two characters from the OCC_CODE column
df['OCC_first_two'] = df['OCC_CODE'].str.split("-").str[0]

# %%
#config dictionary mapping OCC Code to Industry

labor_dictionary = {"11":"Management Occupations",
              "13": "Business and Financial Operations Occupations",
              "15": "Computer and Mathematical Occupations",
              "17": "Architecture and Engineering Occupations",
              "19": "Life, Physical, and Social Science Occupations",
              "21": "Community and Social Service Occupations",
              "23": "Legal Occupations",
              "25": "Educational Instruction and Library Occupations",
              "27": "Arts, Design, Entertainment, Sports, and Media Occupations",
              "29": "Healthcare Practitioners and Technical Occupations",
              "31": "Healthcare Support Occupations",
              "33": "Protective Service Occupations",
              "35": "Food Preparation and Serving Related Occupations",
              "37": "Building and Grounds Cleaning and Maintenance Occupations",
              "39": "Personal Care and Service Occupations",
              "41":"Sales and Related Occupations",
              "43": "Office and Administrative Support Occupations",
              "45": "Farming, Fishing, and Forestry Occupations",
              "47": "Construction and Extraction Occupations",
              "49": "Installation, Maintenance, and Repair Occupations",
              "51": "Production Occupations",
              "53": "Transportation and Material Moving Occupations"
}

# %%
#create a new column which performs a lookup of dictionary values for keys found in OCC_first_two column
df['NBLS Industry'] = df['OCC_first_two'].map(labor_dictionary)

# %%
GICS_sectors = ['Energy',
               'Materials',
               'Consumer Staples',
               'Consumer Discretionary',
               'Industrials',
               'Health Care',
               'Real Estate',
               'Financials',
               'Information Technology',
               'Communication Services',
               'Utilities']

average_wage = {'Energy':106790,
               'Materials':51410,
               'Consumer Staples':46280,
               'Consumer Discretionary':67230,
               'Industrials':49140,
               'Health Care':63710,
               'Real Estate':58530,
               'Financials':88270,
               'Information Technology':105280,
               'Communication Services':47820,
               'Utilities':64760
               }

wages = [106790,51410,46280,67230,49140,63710,58530,88270,105280,47820,64760]

# %%
labor_dictionary = {"11":"Management Occupations",
              "13": "Business and Financial Operations Occupations",
              "15": "Computer and Mathematical Occupations",
              "17": "Architecture and Engineering Occupations",
              "19": "Life, Physical, and Social Science Occupations",
              "21": "Community and Social Service Occupations",
              "23": "Legal Occupations",
              "25": "Educational Instruction and Library Occupations",
              "27": "Arts, Design, Entertainment, Sports, and Media Occupations",
              "29": "Health Care",
              "31": "Health Care",
              "33": "Protective Service Occupations",
              "35": "Food Preparation and Serving Related Occupations",
              "37": "Building and Grounds Cleaning and Maintenance Occupations",
              "39": "Personal Care and Service Occupations",
              "41":"Sales and Related Occupations",
              "43": "Office and Administrative Support Occupations",
              "45": "Farming, Fishing, and Forestry Occupations",
              "47": "Construction and Extraction Occupations",
              "49": "Installation, Maintenance, and Repair Occupations",
              "51": "Production Occupations",
              "53": "Transportation and Material Moving Occupations"
                   }

# %%
NAICS_GICS_mapping = {"Utilities":"Utilities",
                      "Finance and Insurance": "Financials",
                      "Real Estate and Rental and Leasing": "Real Estate",
                      "Health Care and Social Assistance": "Health Care",
                      "Arts, Entertainment, and Recreation": "Communication Services",
                      
}

# %%
data = {'GICS_Sector':GICS_sectors,'Average_wage':wages}
average_wage_df = pd.DataFrame.from_dict(data)

# %%
average_wage_df
# Out:
#                GICS_Sector  Average_wage
# 0                   Energy        106790
# 1                Materials         51410
# 2         Consumer Staples         46280
# 3   Consumer Discretionary         67230
# 4              Industrials         49140
# 5              Health Care         63710
# 6              Real Estate         58530
# 7               Financials         88270
# 8   Information Technology        105280
# 9   Communication Services         47820
# 10               Utilities         64760

# %%
# https://www.bls.gov/opub/reports/womens-databook/2022/home.htm

# %%
total_dict = {'Energy':{"Mining, quarrying, and oil and gas extraction":{"Total":603,
                                                                        "Female":93,
                                                                        "Male":510}
                        },
              
               'Materials':{"Agriculture, forestry, fishing, and hunting":{"Total":2292/2,
                                                                          "Female":642/2,
                                                                          "Male":1650/2}},
               'Consumer Staples':{"Agriculture, forestry, fishing, and hunting":{"Total":2292/2,
                                                                          "Female":642/2,
                                                                          "Male":1650/2},
                                   "Nondurable goods manufacturing":{"Total":5369,
                                                                    "Female":1945,
                                                                    "Male":3424}},
               'Consumer Discretionary':{"Durable goods manufacturing":{"Total":9349,
                                                                       "Female":2357,
                                                                       "Male":6992},
                                         "Wholesale and retail trade":{"Total":19623,
                                                                      "Female":8896,
                                                                      "Male":10727},
                                         "Educational services":{"Total":13521,
                                                                "Female":9349,
                                                                "Male":4172},
                                         "Accommodation and food services":{"Total":9739,
                                                                           "Female":5108,
                                                                           "Male":4631}},
               'Industrials':{"Construction": {"Total":11271,
                                              "Female":1241,
                                              "Male":10030},
                              "Professional and business services": {"Total":19296/2,
                                                                    "Female":8214/2,
                                                                    "Male":11082/2}},
               'Health Care':{"Health care and social assistance":{"Total":21204,
                                                                  "Female":16446,
                                                                  "Male":4757}},
               'Real Estate':{"Real estate and rental and leasing":{"Total":3229,
                                                                   "Female":1586,
                                                                   "Male":1642}},
               'Financials':{"Finance and insurance":{"Total":7497,
                                                     "Female":4002,
                                                     "Male":3495},
                            "Professional and business services": {"Total":19294/2,
                                                                    "Female":8214/2,
                                                                    "Male":11080/2}},
               'Information Technology':{"Information":{"Total":2721,
                                                       "Female":1069,
                                                       "Male":1652}},
               'Communication Services':{"Arts, entertainment, and recreation":{"Total":2896,
                                                                               "Female":1575,
                                                                               "Male":1320}},
               'Utilities':{"Transportation and utilities":{"Total":9377,
                                                           "Female":2325,
                                                           "Male":7052}}}

# %%
total_dict.keys()

for i in total_dict.keys():
    first_level = total_dict.values()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/6h/qf6v8cvn7cg94dskql49_0c00000gn/T/ipykernel_55706/496896434.py in <module>
#       4     first_level = total_dict.values()
#       5
# ----> 6 first_level.keys()
#
# AttributeError: 'dict_values' object has no attribute 'keys'

# %%
def get_all_keys(d):
    for key, value in d.items():
        yield key
        if isinstance(value, dict):
            yield from get_all_keys(value)

for x in get_all_keys(total_dict):
    print(x)

# %%
ratio_list = []
for i in total_dict.keys():
    for j in total_dict[i].keys():
        for x in total_dict[i][j].keys():
            gender_ratio = total_dict[i][j]["Female"]/total_dict[i][j]["Total"]
            ratio_list.append(gender_ratio)
            print(f'The gender_ratio of industry {total_dict[i]} is {gender_ratio}')
# Out:
# The gender_ratio of industry {'Mining, quarrying, and oil and gas extraction': {'Total': 603, 'Female': 93, 'Male': 510}} is 0.15422885572139303
# The gender_ratio of industry {'Mining, quarrying, and oil and gas extraction': {'Total': 603, 'Female': 93, 'Male': 510}} is 0.15422885572139303
# The gender_ratio of industry {'Mining, quarrying, and oil and gas extraction': {'Total': 603, 'Female': 93, 'Male': 510}} is 0.15422885572139303
# The gender_ratio of industry {'Agriculture, forestry, fishing, and hunting': {'Total': 1146.0, 'Female': 321.0, 'Male': 825.0}} is 0.2801047120418848
# The gender_ratio of industry {'Agriculture, forestry, fishing, and hunting': {'Total': 1146.0, 'Female': 321.0, 'Male': 825.0}} is 0.2801047120418848
# The gender_ratio of industry {'Agriculture, forestry, fishing, and hunting': {'Total': 1146.0, 'Female': 321.0, 'Male': 825.0}} is 0.2801047120418848
# ...

# %%
ratio_list
# ratio_list[0::3]

gender_breakdown = {'Energy':.154,
                    'Materials':.280,
                    'Consumer Staples':.346,
                    'Consumer Discretionary':.492,
                    'Industrials':.256,
                    'Health Care':.776,
                    'Real Estate':.491,
                    'Financials':.473,
                    'Information Technology':.393,
                    'Communication Services':.544,
                   'Utilities':.247}

gender_ratios = gender_breakdown.values()
gender_sectors = gender_breakdown.keys()
df_gender = pd.DataFrame(gender_sectors, gender_ratios)
df_gender = df_gender.reset_index()
df_gender
df_gender.rename(columns={'index':'Female %',0:'Sector'})
# Out:
#     Female %                  Sector
# 0      0.154                  Energy
# 1      0.280               Materials
# 2      0.346        Consumer Staples
# 3      0.492  Consumer Discretionary
# 4      0.256             Industrials
# 5      0.776             Health Care
# 6      0.491             Real Estate
# 7      0.473              Financials
# 8      0.393  Information Technology
# 9      0.544  Communication Services
# 10     0.247               Utilities

# %%
df = pd.read_csv('/Users/willcolwell/Desktop/Fintech-Workspace/Challenge1/Parent Leave Cleaned.csv')

df_regular = df

# %%
df1 = df.groupby('Sector').count()

# %%
df1['Difference']= df1["Paid Maternity Leave"] - df1["Paid Paternity Leave"] 
df1['Difference']
df1
# Out:
#                         Company  Industry  Paid Maternity Leave  \
# Sector
# Communication Services      154       153                   154
# Consumer Discretionary      307       307                   307
# Consumer Staples             72        72                    72
# Energy                       14        14                    14
# Financials                  239       238                   239
# Health Care                 141       141                   141
# Industrials                 216       216                   216
# Information Technology      286       285                   286
# Materials                    35        35                    35
# Real Estate                  25        25                    25
# Utilities                    19        19                    19
#
#                         Unpaid Maternity Leave  Paid Paternity Leave  \
# Sector
# Communication Services                     144                    25
# ...

# %%
df2 = df.groupby('Sector').sum().reset_index()

# %%
df2
# Out:
#                     Sector  Paid Maternity Leave  Unpaid Maternity Leave  \
# 0   Communication Services                1756.5                   838.5
# 1   Consumer Discretionary                3158.5                  2080.5
# 2         Consumer Staples                 753.0                   441.5
# 3                   Energy                 137.0                    72.0
# 4               Financials                2850.5                  1450.0
# 5              Health Care                1182.0                   732.0
# 6              Industrials                2115.0                  1460.5
# 7   Information Technology                3664.5                  1620.5
# 8                Materials                 333.5                   243.0
# 9              Real Estate                 225.0                   190.0
# 10               Utilities                 207.5                   166.5
#
#     Paid Paternity Leave  Unpaid Paternity Leave
# ...

# %%
def groupbyfunc(column):
    df2 = df.groupby('Sector')[column].mean()
    return df2

# %%
groupbyfunc('Unpaid Maternity Leave')
# Out:
# Sector
# Communication Services    5.822917
# Consumer Discretionary    7.403915
# Consumer Staples          6.689394
# Energy                    6.545455
# Financials                6.473214
# Health Care               5.587786
# Industrials               7.194581
# Information Technology    5.979705
# Materials                 7.838710
# Real Estate               7.916667
# Utilities                 9.250000
# Name: Unpaid Maternity Leave, dtype: float64

# %%
average_wage_df

merged_df = df2.merge(average_wage_df, left_on='Sector', right_on='GICS_Sector')

# %%
merged_df
# Out:
#                     Sector  Paid Maternity Leave  Unpaid Maternity Leave  \
# 0   Communication Services                1756.5                   838.5
# 1   Consumer Discretionary                3158.5                  2080.5
# 2         Consumer Staples                 753.0                   441.5
# 3                   Energy                 137.0                    72.0
# 4               Financials                2850.5                  1450.0
# 5              Health Care                1182.0                   732.0
# 6              Industrials                2115.0                  1460.5
# 7   Information Technology                3664.5                  1620.5
# 8                Materials                 333.5                   243.0
# 9              Real Estate                 225.0                   190.0
# 10               Utilities                 207.5                   166.5
#
#     Paid Paternity Leave  Unpaid Paternity Leave             GICS_Sector  \
# ...

# %%
merged_df = df_regular.merge(average_wage_df, left_on='Sector', right_on='GICS_Sector')
other_merge =average_wage_df.merge(df_regular, left_on='GICS_Sector', right_on='Sector')
other_merge
# Out:
#      GICS_Sector  Average_wage                           Company  \
# 0         Energy        106790                 BHP Billiton Ltd.
# 1         Energy        106790                             Orica
# 2         Energy        106790                    Enbridge, Inc.
# 3         Energy        106790                        ExxonMobil
# 4         Energy        106790    Marathon Petroleum Corporation
# ...          ...           ...                               ...
# 1503   Utilities         64760                Exelon Corporation
# 1504   Utilities         64760  Pacific Gas and Electric Company
# 1505   Utilities         64760        Southern California Edison
# 1506   Utilities         64760                            Sunrun
# 1507   Utilities         64760                   ISO New England
#
#                                           Industry     Sector  \
# 0               Natural Resources: Metals & Mining     Energy
# ...

# %%
merged_df.to_csv('Merged.csv')

# %%
other_merge
# Out:
#       Paid Paternity Leave  Average_wage
# 0                      2.0        106790
# 14                     6.0         51410
# 15                     6.0         51410
# 17                     0.0         51410
# 18                     4.0         51410
# ...                    ...           ...
# 1416                   6.0         47820
# 1442                  12.0         47820
# 1461                  16.0         47820
# 1489                  16.0         64760
# 1501                   2.0         64760
#
# [280 rows x 2 columns]

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
other_merge = other_merge[['Paid Paternity Leave','Average_wage']].dropna()
other_merge
# Out:
#       Paid Paternity Leave  Average_wage
# 0                      2.0        106790
# 14                     6.0         51410
# 15                     6.0         51410
# 17                     0.0         51410
# 18                     4.0         51410
# ...                    ...           ...
# 1416                   6.0         47820
# 1442                  12.0         47820
# 1461                  16.0         47820
# 1489                  16.0         64760
# 1501                   2.0         64760
#
# [280 rows x 2 columns]

# %%
array2 = other_merge['Paid Paternity Leave'].to_numpy()
array = other_merge['Average_wage'].to_numpy()
array = array.reshape(-1, 1)
array2 = array2.reshape(-1, 1)

# %%
model = LinearRegression().fit(array, array2)

# %%
r_sq = model.score(array, array2)
print(f"coefficient of determination: {r_sq}")
# Out:
# coefficient of determination: 0.03253759563596914

# %%
model = LinearRegression().fit(x, y)

# %%
r_sq = model.score(array, array2)
print(f"coefficient of determination: {r_sq}")

print(f"intercept: {model.intercept_}")


print(f"slope: {model.coef_}")
# Out:
# coefficient of determination: 0.03253759563596914
# intercept: [3.42316171]
# slope: [[5.36838785e-05]]

# %%
from sklearn import datasets, linear_model
import matplotlib.pyplot as plt

# %%
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(array, array2)

# Make predictions using the testing set
# diabetes_y_pred = regr.predict(diabetes_X_test)

# The coefficients
# print("Coefficients: \n", regr.coef_)
# The mean squared error
# print("Mean squared error: %.2f" % mean_squared_error(array, array2))

# Plot outputs
plt.scatter(array, array2, color="black")
# plt.plot(diabetes_X_test, diabetes_y_pred, color="blue", linewidth=3)

plt.xticks(())
plt.yticks(())
# Out:
# ([], [])

# %%
df = pd.read_csv('/Users/willcolwell/Desktop/Fintech-Workspace/Challenge1/Parent_Leave_Cleaned.csv')

df_regular = df
df_regular
# Out:
#                         Company                                   Industry  \
# 0                       Epsilon                                Advertising
# 1       The Walt Disney Company                       Arts & Entertainment
# 2               Guild Education                   Business Services: Other
# 3                        WeWork                   Business Services: Other
# 4                  Randstad USA  Business Services: Staffing & Outsourcing
# ...                         ...                                        ...
# 1596                       Xero                       Technology: Software
# 1597         Fedex Supply Chain        Transportation: Freight & Logistics
# 1598         Schneider National        Transportation: Freight & Logistics
# 1599                  HD Supply                                  Wholesale
# 1600  Merrimac Industrial Sales                                  Wholesale
#
# ...

# %%
df_aggs = df_regular.describe()
df_aggs.iloc[1,:].plot(kind='bar', title = 'Weeks of Leave Across all Industries', ylabel='Weeks of Leave')
# Out:
# <AxesSubplot:title={'center':'Weeks of Leave Across all Industries'}, ylabel='Weeks of Leave'>

# %%
def analysis(column_choice, df):
    '''
    column_choice (Str): column of dataframe you want to analyze
    df (DataFrame): Name of dataframe you want to analyze
    
    returns: box plot of weeks of leave
    '''
    df_regular = df.loc[:,["Sector", column_choice]]
    return df_regular.plot(kind='box')

# %%
analysis('Paid Maternity Leave', df_regular)
# Out:
# <AxesSubplot:>

# %%
data = {'GICS_Sector':GICS_sectors,'Average_wage':wages}
average_wage_df = pd.DataFrame.from_dict(data)

# %%
average_wage_df
# Out:
#                GICS_Sector  Average_wage
# 0                   Energy        106790
# 1                Materials         51410
# 2         Consumer Staples         46280
# 3   Consumer Discretionary         67230
# 4              Industrials         49140
# 5              Health Care         63710
# 6              Real Estate         58530
# 7               Financials         88270
# 8   Information Technology        105280
# 9   Communication Services         47820
# 10               Utilities         64760

# %%
df_regular
# Out:
#                         Company                                   Industry  \
# 0                       Epsilon                                Advertising
# 1       The Walt Disney Company                       Arts & Entertainment
# 2               Guild Education                   Business Services: Other
# 3                        WeWork                   Business Services: Other
# 4                  Randstad USA  Business Services: Staffing & Outsourcing
# ...                         ...                                        ...
# 1596                       Xero                       Technology: Software
# 1597         Fedex Supply Chain        Transportation: Freight & Logistics
# 1598         Schneider National        Transportation: Freight & Logistics
# 1599                  HD Supply                                  Wholesale
# 1600  Merrimac Industrial Sales                                  Wholesale
#
# ...

# %%
df_regular.groupby('Sector')['Paid Maternity Leave'].mean()
# Out:
# Sector
# Communication Services    11.405844
# Consumer Discretionary    10.288274
# Consumer Staples          10.458333
# Energy                     9.785714
# Financials                11.926778
# Health Care                8.382979
# Industrials                9.791667
# Information Technology    12.812937
# Materials                  9.528571
# Real Estate                9.000000
# Utilities                 10.921053
# Name: Paid Maternity Leave, dtype: float64

# %%
def groupbyfunc(column):
    df_groupby = df_regular.groupby('Sector')[column].mean()
    return df_groupby

# %%
groupbyfunc('Unpaid Maternity Leave')
# Out:
# Sector
# Communication Services    5.822917
# Consumer Discretionary    7.403915
# Consumer Staples          6.689394
# Energy                    6.545455
# Financials                6.473214
# Health Care               5.587786
# Industrials               7.194581
# Information Technology    5.979705
# Materials                 7.838710
# Real Estate               7.916667
# Utilities                 9.250000
# Name: Unpaid Maternity Leave, dtype: float64

# %%
df_sector_industry = df_regular.groupby(['Sector','Industry']).mean()

# %%
def industrybreakdown(sector, df=df_regular):
    df_sector_industry = df_regular.groupby(['Sector','Industry']).mean()
    return df_sector_industry.loc[sector,:].plot(kind='bar',rot=90, figsize=(10,10))

# %%
industrybreakdown('Financials')
# Out:
# <AxesSubplot:xlabel='Industry'>

# %%
other_merge.groupby('Sector').mean
# Out:
#      GICS_Sector  Average_wage                           Company  \
# 0         Energy        106790                 BHP Billiton Ltd.
# 1         Energy        106790                             Orica
# 2         Energy        106790                    Enbridge, Inc.
# 3         Energy        106790                        ExxonMobil
# 4         Energy        106790    Marathon Petroleum Corporation
# ...          ...           ...                               ...
# 1503   Utilities         64760                Exelon Corporation
# 1504   Utilities         64760  Pacific Gas and Electric Company
# 1505   Utilities         64760        Southern California Edison
# 1506   Utilities         64760                            Sunrun
# 1507   Utilities         64760                   ISO New England
#
#                                           Industry     Sector  \
# 0               Natural Resources: Metals & Mining     Energy
# ...
